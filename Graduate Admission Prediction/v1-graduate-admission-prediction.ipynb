# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/graduate-admissions/Admission_Predict.csv
# /kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
df = pd.read_csv('/kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv')
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 495         1              0.87
# 496         1              0.96
# 497         1              0.93
# 498         0              0.73
# 499         0              0.84
#
# [500 rows x 9 columns]

# %%
df.drop(columns=['Serial No.'], inplace=True)

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# 2                0.72
# 3                0.80
# 4                0.65
# ..                ...
# 495              0.87
# 496              0.96
# 497              0.93
# 498              0.73
# 499              0.84
#
# [500 rows x 8 columns]

# %%
X = df.iloc[:,:-1]
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y = df.iloc[:, -1]
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y)

# %%
scalar = MinMaxScaler()

X_train_scaled = scalar.fit_transform(X_train)
X_test_scaled = scalar.transform(X_test)

# %%
model = Sequential()

model.add(Dense(7, activation='relu', input_dim=7))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 7)                 56
#
#  dense_1 (Dense)             (None, 10)                80
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 147
# Trainable params: 147
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='Adam')

# %%
history = model.fit(X_train_scaled, y_train, validation_split=0.2, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 1s 9ms/step - loss: 0.6860 - val_loss: 0.3569
# Epoch 2/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1338 - val_loss: 0.0499
# Epoch 3/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0288 - val_loss: 0.0338
# Epoch 4/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0263 - val_loss: 0.0325
# Epoch 5/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0249 - val_loss: 0.0302
# Epoch 6/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0235 - val_loss: 0.0283
# Epoch 7/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.0264
# Epoch 8/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0209 - val_loss: 0.0247
# Epoch 9/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0200 - val_loss: 0.0236
# Epoch 10/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0191 - val_loss: 0.0220
# Epoch 11/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0180 - val_loss: 0.0204
# Epoch 12/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0193
# Epoch 13/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0180
# Epoch 14/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0154 - val_loss: 0.0174
# Epoch 15/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0164
# Epoch 16/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0141 - val_loss: 0.0156
# Epoch 17/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0135 - val_loss: 0.0147
# Epoch 18/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0130 - val_loss: 0.0138
# Epoch 19/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 20/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.0127
# Epoch 21/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0115 - val_loss: 0.0121
# Epoch 22/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0110 - val_loss: 0.0117
# Epoch 23/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0106 - val_loss: 0.0112
# Epoch 24/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0103 - val_loss: 0.0110
# Epoch 25/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0102
# Epoch 26/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.0101
# Epoch 27/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0093
# Epoch 28/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0094
# Epoch 29/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 30/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 31/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 32/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 33/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 34/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0072
# Epoch 35/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0069
# Epoch 36/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0069
# Epoch 37/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0065
# Epoch 38/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0063
# Epoch 39/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0060
# Epoch 40/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 41/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0056
# Epoch 42/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0055
# Epoch 43/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 44/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0051
# Epoch 45/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 46/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 47/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 48/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 49/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 50/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 51/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 52/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 53/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 54/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 55/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 56/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 57/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 58/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 59/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 60/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 61/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 62/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0033
# Epoch 63/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 64/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 65/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0033
# Epoch 66/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0035
# Epoch 67/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 68/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 69/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 70/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 71/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0030
# Epoch 72/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 73/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 74/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 75/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 76/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 77/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 78/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 79/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 80/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 81/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 82/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 83/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 84/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 85/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 86/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 87/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0028
# Epoch 88/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 89/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 90/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 91/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 92/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 93/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 94/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 95/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 96/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 97/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 98/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 99/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 100/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0027

# %%
y_pred = model.predict(X_test_scaled)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7376503265006644

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
