# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bank-customer-churn-prediction/Churn_Modelling.csv

# %%
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('/kaggle/input/bank-customer-churn-prediction/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df = df.drop(columns=['RowNumber', 'CustomerId', 'Surname'])

# %%
df = pd.get_dummies(df, columns=['Geography', 'Gender'], drop_first=True)

# %%
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# 1                  1        112542.58       0                  0
# 2                  0        113931.57       1                  0
# 3                  0         93826.63       0                  0
# 4                  1         79084.10       0                  0
# ...              ...              ...     ...                ...
# 9995               0         96270.64       0                  0
# 9996               1        101699.77       0                  0
# 9997               1         42085.58       1                  0
# 9998               0         92888.52       1                  1
# 9999               0         38190.78       0                  0
#
#       Geography_Spain  Gender_Male
# 0                   0            0
# 1                   1            0
# 2                   0            0
# 3                   0            0
# 4                   1            0
# ...               ...          ...
# 9995                0            1
# 9996                0            1
# 9997                0            0
# 9998                0            1
# 9999                0            0
#
# [10000 rows x 12 columns]

# %%
X = df.drop(columns=['Exited'])
y = df['Exited'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
scaled = StandardScaler()

X_train_scaled = scaled.fit_transform(X_train)
X_test_scaled = scaled.transform(X_test)

# %%
model = Sequential()

model.add(Dense(8,activation='relu',input_dim=11))
model.add(Dense(8,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 8)                 96
#
#  dense_14 (Dense)            (None, 8)                 72
#
#  dense_15 (Dense)            (None, 6)                 54
#
#  dense_16 (Dense)            (None, 4)                 28
#
#  dense_17 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 255
# Trainable params: 255
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics='accuracy')

# %%
history = model.fit(X_train, y_train, epochs=90, batch_size=50, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 1s 4ms/step - loss: 4971.5103 - accuracy: 0.3842 - val_loss: 562.3224 - val_accuracy: 0.6600
# Epoch 2/100
# 128/128 [==============================] - 0s 2ms/step - loss: 185.6280 - accuracy: 0.6672 - val_loss: 26.2595 - val_accuracy: 0.7163
# Epoch 3/100
# 128/128 [==============================] - 0s 2ms/step - loss: 17.7237 - accuracy: 0.7038 - val_loss: 8.7549 - val_accuracy: 0.7225
# Epoch 4/100
# 128/128 [==============================] - 0s 2ms/step - loss: 8.7474 - accuracy: 0.7242 - val_loss: 7.5793 - val_accuracy: 0.5337
# Epoch 5/100
# 128/128 [==============================] - 0s 2ms/step - loss: 5.3269 - accuracy: 0.7336 - val_loss: 2.5916 - val_accuracy: 0.7431
# Epoch 6/100
# 128/128 [==============================] - 0s 2ms/step - loss: 3.2715 - accuracy: 0.7320 - val_loss: 1.8654 - val_accuracy: 0.7744
# Epoch 7/100
# 128/128 [==============================] - 0s 2ms/step - loss: 2.3891 - accuracy: 0.7278 - val_loss: 2.0093 - val_accuracy: 0.7844
# Epoch 8/100
# 128/128 [==============================] - 0s 2ms/step - loss: 2.3448 - accuracy: 0.7706 - val_loss: 2.1017 - val_accuracy: 0.7763
# Epoch 9/100
# 128/128 [==============================] - 0s 2ms/step - loss: 1.7165 - accuracy: 0.7873 - val_loss: 1.2710 - val_accuracy: 0.7937
# Epoch 10/100
# 128/128 [==============================] - 0s 2ms/step - loss: 1.1127 - accuracy: 0.7772 - val_loss: 0.9402 - val_accuracy: 0.7937
# Epoch 11/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.8037 - accuracy: 0.7859 - val_loss: 0.6669 - val_accuracy: 0.7950
# Epoch 12/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.6400 - accuracy: 0.7856 - val_loss: 0.5665 - val_accuracy: 0.7744
# Epoch 13/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5639 - accuracy: 0.7862 - val_loss: 0.5256 - val_accuracy: 0.7975
# Epoch 14/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5529 - accuracy: 0.7866 - val_loss: 0.5447 - val_accuracy: 0.7975
# Epoch 15/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5288 - accuracy: 0.7928 - val_loss: 0.5417 - val_accuracy: 0.7975
# Epoch 16/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5321 - accuracy: 0.7889 - val_loss: 0.5169 - val_accuracy: 0.7794
# Epoch 17/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5253 - accuracy: 0.7906 - val_loss: 0.5384 - val_accuracy: 0.7669
# Epoch 18/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5622 - accuracy: 0.7867 - val_loss: 0.6461 - val_accuracy: 0.7525
# Epoch 19/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5533 - accuracy: 0.7853 - val_loss: 0.5544 - val_accuracy: 0.7975
# Epoch 20/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5208 - accuracy: 0.7953 - val_loss: 0.5124 - val_accuracy: 0.7819
# Epoch 21/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5182 - accuracy: 0.7937 - val_loss: 0.5154 - val_accuracy: 0.7744
# Epoch 22/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5542 - accuracy: 0.7866 - val_loss: 0.5125 - val_accuracy: 0.7975
# Epoch 23/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5321 - accuracy: 0.7891 - val_loss: 0.5512 - val_accuracy: 0.7669
# Epoch 24/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5323 - accuracy: 0.7878 - val_loss: 0.5217 - val_accuracy: 0.7675
# Epoch 25/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5384 - accuracy: 0.7887 - val_loss: 0.5156 - val_accuracy: 0.7975
# Epoch 26/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5281 - accuracy: 0.7905 - val_loss: 0.5055 - val_accuracy: 0.7975
# Epoch 27/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5318 - accuracy: 0.7905 - val_loss: 0.5315 - val_accuracy: 0.7975
# Epoch 28/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5254 - accuracy: 0.7897 - val_loss: 0.5291 - val_accuracy: 0.7975
# Epoch 29/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5201 - accuracy: 0.7920 - val_loss: 0.5052 - val_accuracy: 0.7975
# Epoch 30/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5247 - accuracy: 0.7911 - val_loss: 0.5084 - val_accuracy: 0.7975
# Epoch 31/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5343 - accuracy: 0.7898 - val_loss: 0.5029 - val_accuracy: 0.7975
# Epoch 32/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5213 - accuracy: 0.7923 - val_loss: 0.5117 - val_accuracy: 0.7812
# Epoch 33/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5142 - accuracy: 0.7937 - val_loss: 0.5037 - val_accuracy: 0.7975
# Epoch 34/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5170 - accuracy: 0.7930 - val_loss: 0.5085 - val_accuracy: 0.7975
# Epoch 35/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5138 - accuracy: 0.7936 - val_loss: 0.5077 - val_accuracy: 0.7875
# Epoch 36/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5142 - accuracy: 0.7934 - val_loss: 0.5023 - val_accuracy: 0.7975
# Epoch 37/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5150 - accuracy: 0.7931 - val_loss: 0.5019 - val_accuracy: 0.7975
# Epoch 38/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5160 - accuracy: 0.7941 - val_loss: 0.5192 - val_accuracy: 0.7975
# Epoch 39/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5124 - accuracy: 0.7953 - val_loss: 0.5030 - val_accuracy: 0.7969
# Epoch 40/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5111 - accuracy: 0.7958 - val_loss: 0.5092 - val_accuracy: 0.7850
# Epoch 41/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5112 - accuracy: 0.7948 - val_loss: 0.5035 - val_accuracy: 0.7975
# Epoch 42/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5114 - accuracy: 0.7942 - val_loss: 0.5011 - val_accuracy: 0.7975
# Epoch 43/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5088 - accuracy: 0.7958 - val_loss: 0.5043 - val_accuracy: 0.7950
# Epoch 44/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5088 - accuracy: 0.7959 - val_loss: 0.5014 - val_accuracy: 0.7975
# Epoch 45/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5097 - accuracy: 0.7962 - val_loss: 0.5057 - val_accuracy: 0.7975
# Epoch 46/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5075 - accuracy: 0.7961 - val_loss: 0.5023 - val_accuracy: 0.7975
# Epoch 47/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.7964 - val_loss: 0.5089 - val_accuracy: 0.7969
# Epoch 48/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5076 - accuracy: 0.7953 - val_loss: 0.5022 - val_accuracy: 0.7950
# Epoch 49/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5057 - accuracy: 0.7967 - val_loss: 0.5008 - val_accuracy: 0.7975
# Epoch 50/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.7966 - val_loss: 0.5012 - val_accuracy: 0.7975
# Epoch 51/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.7958 - val_loss: 0.5026 - val_accuracy: 0.7956
# Epoch 52/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5052 - accuracy: 0.7967 - val_loss: 0.5007 - val_accuracy: 0.7975
# Epoch 53/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5050 - accuracy: 0.7967 - val_loss: 0.5005 - val_accuracy: 0.7975
# Epoch 54/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5051 - accuracy: 0.7967 - val_loss: 0.5006 - val_accuracy: 0.7975
# Epoch 55/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5052 - accuracy: 0.7969 - val_loss: 0.4999 - val_accuracy: 0.7975
# Epoch 56/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.7969 - val_loss: 0.4998 - val_accuracy: 0.7975
# Epoch 57/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5042 - accuracy: 0.7972 - val_loss: 0.5004 - val_accuracy: 0.7975
# Epoch 58/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5050 - accuracy: 0.7972 - val_loss: 0.4999 - val_accuracy: 0.7975
# Epoch 59/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.7972 - val_loss: 0.5004 - val_accuracy: 0.7975
# Epoch 60/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.7972 - val_loss: 0.5005 - val_accuracy: 0.7975
# Epoch 61/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5049 - accuracy: 0.7966 - val_loss: 0.5022 - val_accuracy: 0.7975
# Epoch 62/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5042 - accuracy: 0.7970 - val_loss: 0.4994 - val_accuracy: 0.7975
# Epoch 63/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5046 - accuracy: 0.7958 - val_loss: 0.4991 - val_accuracy: 0.7975
# Epoch 64/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5038 - accuracy: 0.7967 - val_loss: 0.5003 - val_accuracy: 0.7975
# Epoch 65/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.7972 - val_loss: 0.5002 - val_accuracy: 0.7975
# Epoch 66/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5032 - accuracy: 0.7972 - val_loss: 0.4998 - val_accuracy: 0.7975
# Epoch 67/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5037 - accuracy: 0.7966 - val_loss: 0.4997 - val_accuracy: 0.7975
# Epoch 68/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5039 - accuracy: 0.7972 - val_loss: 0.4991 - val_accuracy: 0.7975
# Epoch 69/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.7972 - val_loss: 0.4994 - val_accuracy: 0.7975
# Epoch 70/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5025 - accuracy: 0.7972 - val_loss: 0.4988 - val_accuracy: 0.7975
# Epoch 71/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5026 - accuracy: 0.7972 - val_loss: 0.4986 - val_accuracy: 0.7975
# Epoch 72/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.7972 - val_loss: 0.4985 - val_accuracy: 0.7975
# Epoch 73/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5022 - accuracy: 0.7972 - val_loss: 0.4985 - val_accuracy: 0.7975
# Epoch 74/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5022 - accuracy: 0.7972 - val_loss: 0.4999 - val_accuracy: 0.7975
# Epoch 75/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5026 - accuracy: 0.7972 - val_loss: 0.4996 - val_accuracy: 0.7975
# Epoch 76/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.7972 - val_loss: 0.5004 - val_accuracy: 0.7975
# Epoch 77/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5022 - accuracy: 0.7972 - val_loss: 0.4988 - val_accuracy: 0.7975
# Epoch 78/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7972 - val_loss: 0.4984 - val_accuracy: 0.7975
# Epoch 79/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5022 - accuracy: 0.7972 - val_loss: 0.5024 - val_accuracy: 0.7975
# Epoch 80/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5015 - accuracy: 0.7972 - val_loss: 0.4988 - val_accuracy: 0.7975
# Epoch 81/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5021 - accuracy: 0.7972 - val_loss: 0.5001 - val_accuracy: 0.7975
# Epoch 82/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5023 - accuracy: 0.7972 - val_loss: 0.4991 - val_accuracy: 0.7975
# Epoch 83/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7972 - val_loss: 0.5053 - val_accuracy: 0.7975
# Epoch 84/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5052 - accuracy: 0.7972 - val_loss: 0.5044 - val_accuracy: 0.7975
# Epoch 85/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5046 - accuracy: 0.7972 - val_loss: 0.5040 - val_accuracy: 0.7975
# Epoch 86/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.7972 - val_loss: 0.5039 - val_accuracy: 0.7975
# Epoch 87/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.7972 - val_loss: 0.5039 - val_accuracy: 0.7975
# Epoch 88/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5039 - val_accuracy: 0.7975
# Epoch 89/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5039 - val_accuracy: 0.7975
# Epoch 90/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5038 - val_accuracy: 0.7975
# Epoch 91/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5038 - val_accuracy: 0.7975
# Epoch 92/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5038 - val_accuracy: 0.7975
# Epoch 93/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5038 - val_accuracy: 0.7975
# Epoch 94/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5038 - val_accuracy: 0.7975
# Epoch 95/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5039 - val_accuracy: 0.7975
# Epoch 96/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5038 - val_accuracy: 0.7975
# Epoch 97/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5038 - val_accuracy: 0.7975
# Epoch 98/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5038 - val_accuracy: 0.7975
# Epoch 99/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5038 - val_accuracy: 0.7975
# Epoch 100/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 0.5038 - val_accuracy: 0.7975

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7925

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
